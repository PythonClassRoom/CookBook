# %%
import random

# %%
import numpy as np
import random

# %%
def randomFunction(tam=10000):
    return random.randint(a=-tam,b=tam)*np.ones(random.randint(a=1,b=tam))

# %%
data
v=range(0,100)
for i in range(1000):
    data=random.choice(v)
    print(data)
# Out:
# 81
# 84
# 30
# 47
# 9
# 90
# 86
# 50
# 37
# 31
# 34
# 97
# 82
# 18
# 7
# 8
# 16
# 81
# 61
# 71
# 89
# 76
# 57
# 51
# 88
# 96
# 17
# 0
# 30
# 54
# 52
# 13
# 31
# 57
# 92
# 42
# 0
# 26
# 50
# 97
# 62
# 41
# 10
# 51
# 54
# 79
# 68
# 77
# 33
# 97
# 98
# 62
# 96
# 98
# 40
# 64
# 34
# 47
# 54
# 26
# 5
# 27
# 1
# 41
# 84
# 70
# 72
# 67
# 50
# 0
# 95
# 92
# 87
# 80
# 43
# 83
# 82
# 53
# 16
# 12
# 23
# 49
# 25
# 20
# 40
# 19
# 70
# 80
# 86
# 38
# 59
# 67
# 57
# 66
# 93
# 11
# 65
# 91
# 86
# 64
# 91
# 86
# 15
# 67
# 46
# 39
# 40
# 30
# 94
# 19
# 71
# 70
# 34
# 4
# 60
# 86
# 47
# 9
# 23
# 33
# 52
# 62
# 48
# 35
# 18
# 37
# 18
# 51
# 87
# 66
# 30
# 93
# 16
# 52
# 36
# 41
# 85
# 99
# 89
# 92
# 25
# 5
# 58
# 73
# 31
# 86
# 61
# 39
# 73
# 5
# 41
# 90
# 35
# 74
# 75
# 74
# 97
# 28
# 80
# 20
# 87
# 19
# 68
# 9
# 18
# 78
# 28
# 78
# 96
# 52
# 72
# 55
# 45
# 57
# 24
# 53
# 72
# 71
# 27
# 19
# 32
# 8
# 17
# 91
# 71
# 9
# 43
# 14
# 73
# 37
# 19
# 77
# 90
# 1
# 51
# 76
# 10
# 16
# 72
# 85
# 80
# 83
# 90
# ...

# %%
array
# Out:
# array([ 1687.,  1687.,  1687., ..., -8966., -8966., -8966.])

# %%
import random
from matplotlib.pylab import hist, show
v=range(0,100)
data=[]
for i in range(1000):
    data.append(random.choice(v))

hist(data,30, (0,100),facecolor='Orange')
show()

# %%
def _funcion_():
    v=range(0,100)
    data=[]
    for i in range(1000):
        data.append(random.choice(v))

    hist(data,30, (0,100),facecolor='Purple')
    show()

# %%
_funcion_()
